# %% [markdown]
# # Using pygrib to explore HRRR model output
# pygrib example usgae: http://nbviewer.jupyter.org/gist/jswhit/8635665

# %%
# %matplotlib inline
import pygrib
import matplotlib.pyplot as plt

# %%
DIR = '/uufs/chpc.utah.edu/common/home/u0553130/temp/'
FILE = '20171201_hrrr.t14z.wrfprsf00.grib2_earlyLook.grib2'

grb = pygrib.open(DIR+FILE)

# %% [markdown]
# Print a list of fields

# %%
for i in grb:
    print i
# Out:
# 1:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712011400
# 2:Temperature:K (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712011400
# 3:Relative humidity:% (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712011400
# 4:Dew point temperature:K (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712011400
# 5:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712011400
# 6:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712011400
# 7:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712011400
# 8:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712011400
# 9:Absolute vorticity:s**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201712011400
# ...
