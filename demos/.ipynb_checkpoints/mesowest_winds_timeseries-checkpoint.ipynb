# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import sys

sys.path.append('/uufs/chpc.utah.edu/common/home/u0553130/pyBKB_v2')

from BB_MesoWest.MesoWest_timeseries import get_mesowest_ts
from BB_wx_calcs.wind import *

# Hour locator
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
formatter = DateFormatter('%b-%d\n%H:%M')

import matplotlib as mpl 
mpl.rcParams['figure.figsize'] = [10, 5]
mpl.rcParams['figure.titlesize'] = 12
mpl.rcParams['figure.titleweight'] = 'bold'
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['axes.labelsize'] = 12
mpl.rcParams['axes.titlesize'] = 14
mpl.rcParams['lines.linewidth'] = 1.8
mpl.rcParams['grid.linewidth'] = .25
mpl.rcParams['figure.subplot.wspace'] = 0.05
mpl.rcParams['figure.subplot.hspace'] = 0.05
mpl.rcParams['legend.fontsize'] = 10
mpl.rcParams['legend.framealpha'] = .75
mpl.rcParams['legend.loc'] = 'best'
mpl.rcParams['legend.scatterpoints'] = 1
mpl.rcParams['savefig.bbox'] = 'tight'

# %%
sDATE = datetime(2018, 4, 12, 0)
eDATE = datetime(2018, 4, 13, 0)
A = get_mesowest_ts('QSF', sDATE, eDATE, variables='wind_speed,wind_direction,wind_gust')
a = get_mesowest_ts('UKBKB', sDATE, eDATE, variables='wind_speed,wind_direction,wind_gust')
b = get_mesowest_ts('C9348', sDATE, eDATE, variables='wind_speed,wind_direction,wind_gust')
c = get_mesowest_ts('UCC13', sDATE, eDATE, variables='wind_speed,wind_direction,wind_gust')

# %%
A.keys()
# Out:
# ['wind_speed',
#  'ELEVATION',
#  'NAME',
#  'URL',
#  'STID',
#  'LON',
#  'DATETIME',
#  'LAT',
#  'wind_direction']

# %%
local = [d - timedelta(hours=6) for d in A['DATETIME']]

fig = plt.figure()
ax1 = fig.add_subplot(111)

plt.sca(ax1)
plt.plot(local, A['wind_speed']*2.2369,
         label='Wind Speed',
         color='darkblue',
         zorder=1)

ax2 = ax1.twinx()
plt.sca(ax2)
ax2.scatter(local, A['wind_direction'],
            label='Wind Direction',
            color=[.5,.5,.5],
            zorder=10
           )
ax2.set_ylim([0,360])
ax2.set_yticks(range(0,361,45))
ax2.set_yticklabels(['N','NE','E','SE','S','SW','W','NW','N',])
ax2.set_ylabel(r'Wind Direction')

ax1.set_xlim([sDATE- timedelta(hours=6), eDATE- timedelta(hours=6)])
ax1.set_ylim(ymin=0)
ax1.set_ylabel(r'Wind Speed (MPH)')

legend = ax1.legend(frameon=True, framealpha=.9, loc='upper left', scatterpoints=1)
legend.get_frame().set_linewidth(0)
legend.set_zorder(100)
ax1.xaxis.set_major_locator(mdates.HourLocator(range(0, 24, 3)))
ax1.xaxis.set_minor_locator(mdates.HourLocator(range(0, 24, 1)))
ax1.xaxis.set_major_formatter(formatter)

ax1.grid()
plt.title('%s' % (A['NAME']), fontweight='semibold')
plt.savefig('./%s_wind' % a['STID'])

# %%
local = [d - timedelta(hours=6) for d in a['DATETIME']]
plt.plot(local, a['wind_speed']*2.2369,
         label='Wind Speed',
         color='darkblue')
plt.scatter(local, a['wind_gust']*2.2369,
            color='darkgreen',
            label='Gust')

plt.xlim([sDATE- timedelta(hours=6), eDATE- timedelta(hours=6)])
plt.ylim(ymin=0)
plt.ylabel(r'Wind Speed (MPH)')

ax = plt.gca()
legend = ax.legend(frameon=True, framealpha=.5)
legend.get_frame().set_linewidth(0)
ax.xaxis.set_major_locator(mdates.HourLocator(range(0, 24, 3)))
ax.xaxis.set_minor_locator(mdates.HourLocator(range(0, 24, 1)))
ax.xaxis.set_major_formatter(formatter)

plt.grid()
plt.title('%s' % (a['NAME']), fontweight='semibold')
plt.savefig('./%s_wind' % a['STID'])

# %%
local = [d - timedelta(hours=6) for d in b['DATETIME']]
plt.plot(local, b['wind_speed']*2.2369,
         label='Wind Speed',
         color='darkblue')
plt.scatter(local, b['wind_gust']*2.2369,
            color='darkgreen',
            label='Gust')

plt.xlim([sDATE- timedelta(hours=6), eDATE- timedelta(hours=6)])
plt.ylim(ymin=0)
plt.ylabel(r'Wind Speed (MPH)')

ax = plt.gca()
legend = ax.legend(frameon=True, framealpha=.5)
legend.get_frame().set_linewidth(0)
ax.xaxis.set_major_locator(mdates.HourLocator(range(0, 24, 3)))
ax.xaxis.set_minor_locator(mdates.HourLocator(range(0, 24, 1)))
ax.xaxis.set_major_formatter(formatter)

plt.grid()
plt.title('%s' % (b['NAME']), fontweight='semibold')
plt.savefig('./%s_wind' % b['STID'])

# %%
local = [d - timedelta(hours=6) for d in c['DATETIME']]
plt.plot(local, c['wind_speed']*2.2369,
         label='Wind Speed',
         color='darkblue')
plt.scatter(local, c['wind_gust']*2.2369,
            color='darkgreen',
            label='Gust')

plt.xlim([sDATE-timedelta(hours=6), eDATE-timedelta(hours=6)])
plt.ylim(ymin=0)
plt.ylabel(r'Wind Speed (MPH)')

ax = plt.gca()
legend = ax.legend(frameon=True, framealpha=.5)
legend.get_frame().set_linewidth(0)
ax.xaxis.set_major_locator(mdates.HourLocator(range(0, 24, 3)))
ax.xaxis.set_minor_locator(mdates.HourLocator(range(0, 24, 1)))
ax.xaxis.set_major_formatter(formatter)

plt.grid()
plt.title('%s %s' % (c['STID'], c['NAME']), fontweight='semibold')
plt.savefig('./%s_wind2' % c['STID'])

# %%
u, v = wind_spddir_to_uv(c['wind_speed']*2.2369, c['wind_direction'])

# %%
local = [d - timedelta(hours=6) for d in c['DATETIME']]
idx = mpl.dates.date2num(local)

Q = plt.quiver(idx, 0, u, v, label='direction', width=.005)
#plt.barbs(idx, 0, u, v, label='direction')

plt.xlim([sDATE- timedelta(hours=6), eDATE- timedelta(hours=6)])
#plt.ylim(ymin=0)
plt.yticks([])
plt.ylabel(r'Wind Speed (MPH)')
plt.axhline(y=0, color='grey')

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.HourLocator(range(0, 24, 3)))
ax.xaxis.set_minor_locator(mdates.HourLocator(range(0, 24, 1)))
ax.xaxis.set_major_formatter(formatter)

qk = plt.quiverkey(Q, .90, 0.1, 10, r'10 m s$^{-1}$',
                   labelpos='S',
                   coordinates='axes',
                   color='magenta')
qk.text.set_backgroundcolor('w')

# %%
sDATE = datetime(2017, 11, 1, 0)
eDATE = datetime.now()
d = get_mesowest_ts('SLCBY', sDATE, eDATE, variables='air_temp')

# %%
local = [D - timedelta(hours=6) for D in d['DATETIME']]
plt.plot(local, d['air_temp'],
         label='air_temp',
         color='crimson')

plt.xlim([sDATE-timedelta(hours=6), eDATE-timedelta(hours=6)])
plt.ylim(ymin=0)
plt.ylabel(r'Air Temperature (C)')

ax = plt.gca()
legend = ax.legend(frameon=True, framealpha=.5)
legend.get_frame().set_linewidth(0)
ax.xaxis.set_major_locator(mdates.DayLocator([1]))
#ax.xaxis.set_minor_locator(mdates.HourLocator(range(0, 24, 1)))
ax.xaxis.set_major_formatter(formatter)

plt.grid()
plt.title('%s %s' % (d['STID'], d['NAME']), fontweight='semibold')

# %%
d['air_temp'][d['air_temp']==999] = np.nan
