# %% [markdown]
# # Time Series HRRR Statistics from OSG

# %%
# %matplotlib inline
import h5py
import matplotlib.pyplot as plt
import multiprocessing
import numpy as np
from collections import OrderedDict

import sys
import sys
sys.path.append('/uufs/chpc.utah.edu/common/home/u0553130/pyBKB_v2')
from BB_downloads.HRRR_S3 import *
from BB_wx_calcs.wind import wind_uv_to_spd
from BB_basemap.draw_maps import draw_CONUS_HRRR_map
from BB_MesoWest.MesoWest_STNinfo import get_MW_location_dict
from BB_MesoWest.MesoWest_timeseries import get_mesowest_ts
from BB_data.grid_manager import pluck_point_new

# %%
from matplotlib.dates import DateFormatter
formatter = DateFormatter('%b\n%d')

import matplotlib as mpl 
mpl.rcParams['figure.figsize'] = [15, 6]
mpl.rcParams['figure.titlesize'] = 15
mpl.rcParams['figure.titleweight'] = 'bold'
mpl.rcParams['xtick.labelsize'] = 10
mpl.rcParams['ytick.labelsize'] = 10
mpl.rcParams['axes.labelsize'] = 10
mpl.rcParams['axes.titlesize'] = 12
mpl.rcParams['lines.linewidth'] = 1.8
mpl.rcParams['grid.linewidth'] = .25
mpl.rcParams['figure.subplot.wspace'] = 0.05
mpl.rcParams['figure.subplot.hspace'] = 0.05
mpl.rcParams['legend.fontsize'] = 8
mpl.rcParams['legend.framealpha'] = .75
mpl.rcParams['legend.loc'] = 'best'
mpl.rcParams['savefig.bbox'] = 'tight'
mpl.rcParams['savefig.dpi'] = 300

# %%
m = draw_CONUS_HRRR_map()

# %% [markdown]
# ### Get lat/lon grid from file for plotting

# %%
DIR = '/uufs/chpc.utah.edu/common/home/horel-group2/blaylock/HRRR_OSG/'
latlon_file = h5py.File(DIR+'OSG_HRRR_latlon.h5', 'r')
lat = latlon_file['latitude'].value
lon = latlon_file['longitude'].value

# %% [markdown]
# ### Get a point from the grid (multiprocessor)

# %%
def get_point_MP(inputs):
    """
    Function for MultiProcessing:
    Return the value from a point in the HDF5 file array
    """
    FILE, STAT, ROW, COL = inputs
    try:
        with h5py.File(FILE, 'r') as f:
            return f[STAT][ROW][COL]
    except:
        #print "COULD NOT GET", FILE
        return np.nan

# %% [markdown]
# -------

# %% [markdown]
# # Time Series

# %% [markdown]
# ### Input Arguments
# statistic can be from the list:
# `mean, p00, p01, p02, p03, p04, p05, p10, p15, p25, p33, p50, p66, p75, p90, p95, p96, p97, p98, p99, p100`

# %%
statistics = ['p00', 'p05', 'p25', 'p50', 'p75', 'p95', 'p100']
#statistics = ['p05', 'p50', 'p95']
var = 'UVGRD:10 m'
stn = 'HWKC1'
fxx = 0

hours = range(24)
#hours = [18]

# Range to get MesoWest and HRRR values (eDATE is exclusive)
sDATE = datetime(2017, 10, 8)
eDATE = datetime(2017, 10, 11)

plot_HRRR = True
plot_MW = True
plot_POLYWOG = True

# %% [markdown]
# ##### Additional Setup

# %%
variable = var.replace(':', '_').replace(' ', '_')
DIR = '/uufs/chpc.utah.edu/common/home/horel-group2/blaylock/HRRR_OSG/hourly30/%s/' % (variable)

if var == 'TMP:2 m':
    MWvar = 'air_temp'
elif var == 'DPT:2 m':
    MWvar = 'dew_point_temperature'
elif var == 'UVGRD:10 m':
    MWvar = 'wind_speed'
elif var == 'UVGRD:80 m':
    MWvar = 'wind_speed'
else:
    print "NO MATCHING VAR AND MESOWEST VAR"

if (eDATE-sDATE).days < 365:
    months = np.arange(sDATE.month,eDATE.month+1)
else:
    months = np.arange(1,13)

days = [31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

# Dates (with leap year)
DAYS = days[months[0]-1:months[-1]]
HOURS = np.sum(DAYS)*24 # number of days times 24
DATES = np.array([datetime(2016, sDATE.month, sDATE.day) + timedelta(hours = h) for h in range(HOURS)])
DATES = DATES[::24/len(hours)] # in case we don't request all 24 hours


# Plot Window (convert needs to be a leap year, so use 2016)
if (eDATE-sDATE).days >=365:
    sPLOT = datetime(2016, sDATE.month, sDATE.day, sDATE.hour)
    ePLOT = datetime(2017, eDATE.month, eDATE.day, eDATE.hour)
else:
    sPLOT = datetime(2016, sDATE.month, sDATE.day, sDATE.hour)
    ePLOT = datetime(2016, eDATE.month, eDATE.day, eDATE.hour)

# %% [markdown]
# ### Get a HRRR and MesoWest time series for a point

# %%
# MesoWest Station Info
LD = get_MW_location_dict(stn)
MWlat = LD[stn]['latitude']
MWlon = LD[stn]['longitude']

# Get MewsoWest Time Series
if plot_MW:
    # Get MesoWest Time Series
    a = get_mesowest_ts(stn, sDATE, eDATE, variables=MWvar,)

    # Convert datetime to a leap year date so we can easily plot them with percentiles, sharing the axis.
    MW_DATES = [datetime(2016, d.month, d.day, d.hour, d.minute) for d in a['DATETIME']]

# Get HRRR Time Series for analysis (f00)
if plot_HRRR:
    if var == 'UVGRD:10 m':
        """
        HRRR_date, U = point_hrrr_time_series(sDATE, eDATE,
                                              variable='UGRD:10 m',
                                              lat=MWlat, lon=MWlon,
                                              verbose=False)
        HRRR_date, V = point_hrrr_time_series(sDATE, eDATE,
                                              variable='UGRD:10 m',
                                              lat=MWlat, lon=MWlon,
                                              verbose=False)
        HRRR_val = wind_uv_to_spd(U, V)
        """
        HRRR_date, HRRR_val = point_hrrr_time_series(sDATE, eDATE,
                                                     variable='WIND:10 m',
                                                     lat=MWlat, lon=MWlon,
                                                     verbose=False)

    else:
        HRRR_date, HRRR_val = point_hrrr_time_series(sDATE, eDATE,
                                                     variable='TMP:2 m',
                                                     lat=MWlat, lon=MWlon,
                                                     verbose=False)
        HRRR_val = HRRR_val-273.15

    HRRR_DATES = [datetime(2016, d.month, d.day, d.hour, d.minute) for d in HRRR_date]
# Out:
# f00: finished multiprocessing in 0:00:09.347263 on 22 processers

# %% [markdown]
# ### Get HRRR Percentile Data

# %%
# Get Time Series Data for each requested Statistic
# HTS is the HRRR-statistic Time Series

# Pluck point
point = pluck_point_new(MWlat, MWlon, lat, lon)

print "Station:", stn
print "Grid Point:", point
print "Variable:", var, 'and', MWvar
print "Statistic:", statistics

HTS = OrderedDict()
for i, stat in enumerate(statistics):
    # Multiprocessing :)
    args = [[DIR+'OSG_HRRR_%s_m%02d_d%02d_h%02d_f00.h5' % \
            (variable, month, day, hour), stat, point[0][0], point[1][0]] \
            for month in months for day in range(1,days[month-1]+1) for hour in hours]
    timer = datetime.now()
    num_proc = multiprocessing.cpu_count()
    p = multiprocessing.Pool(num_proc)
    HTS[stat] = np.array(p.map(get_point_MP, args))
    p.close()
    if var == 'TMP:2 m':
        HTS[stat] = HTS[stat]-273.15
        ylabel = '2 m Temperature (C)'
    elif var == 'DPT:2 m':
        HTS[stat] = HTS[stat]-273.15
        ylabel = '2 m Dew Point (C)'
    elif var == 'UVGRD:10 m':
        ylabel = r'10 m Wind Speed (m s$\mathregular{^{-1}}$)'
    elif var == 'UVGRD:80 m':
        ylabel = r'80 m Wind Speed (m s$\mathregular{^{-1}}$)'
    elif var == 'REFC:entire':
        ylabel = 'Simulated Composite Reflecivity (dBZ)'
    print "%s Timer:%s" % (stat, datetime.now()-timer)
# Out:
# Station: HWKC1
# Grid Point: (array([638]), array([176]))
# Variable: UVGRD:10 m and wind_speed
# Statistic: ['p00', 'p05', 'p25', 'p50', 'p75', 'p95', 'p100']
# p00 Timer:0:00:09.305611
# p05 Timer:0:00:07.512808
# p25 Timer:0:00:07.546083
# p50 Timer:0:00:08.061367
# p75 Timer:0:00:08.085857
# p95 Timer:0:00:09.004618
# p100 Timer:0:00:08.434893

# %% [markdown]
# ### Plot all Percentiles Requested

# %%
for i, stat in enumerate(HTS.keys()):  
    plt.plot(DATES, HTS[stat], label=stat)

plt.title('Station: %s\nVariable: %s\nHours:%s' % (stn, var, hours))
plt.ylabel(ylabel)

plt.gca().xaxis.set_major_formatter(formatter)

if plot_MW:
    plt.plot(MW_DATES, a[MWvar], label='MesoWest', color='k', lw=0.4)

plt.xlim([sPLOT, ePLOT])
plt.legend()
plt.grid()

# %% [markdown]
# ### Fill Between 5-50 and 50-95 Percentiles

# %%
plt.fill_between(DATES, HTS['p05'], HTS['p50'], facecolor='lightgrey',linewidth=0, label='p05-p50')
plt.fill_between(DATES, HTS['p50'], HTS['p95'], facecolor='grey', linewidth=0, label='p50-p95')

plt.title('Station: %s\nVariable: %s\nHours:%s' % (stn, var, hours))
plt.ylabel(ylabel)

plt.gca().xaxis.set_major_formatter(formatter)

if plot_MW:
    plt.plot(MW_DATES, a[MWvar], label='MesoWest', color='k', lw=0.7)

if plot_HRRR:
    plt.plot(HRRR_DATES, HRRR_val, color='r', label='HRRR f00')

plt.xlim([sPLOT, ePLOT])
plt.legend()
plt.grid()

# %%
plt.fill_between(DATES, HTS['p25'], HTS['p75'], facecolor='grey', linewidth=0, label='p25-p75')
plt.fill_between(DATES, HTS['p75'], HTS['p95'], facecolor='lightgrey', linewidth=0, label='p05-p95')
plt.fill_between(DATES, HTS['p05'], HTS['p25'], facecolor='lightgrey', linewidth=0)
plt.plot(DATES, HTS['p50'], color='w', lw=.5, label='p50')
plt.plot(DATES, HTS['p100'], color='k', lw=.5, label='max, min')
plt.plot(DATES, HTS['p00'], color='k', lw=.5)
plt.title('Station: %s\nVariable: %s\nHours:%s' % (stn, var, hours))
plt.ylabel(ylabel)

plt.gca().xaxis.set_major_formatter(formatter)

if plot_MW:
    plt.plot(MW_DATES, a[MWvar], label='MesoWest', color='k', lw=0.7)

if plot_HRRR:
    plt.plot(HRRR_DATES, HRRR_val, color='r', label='HRRR f00')

plt.xlim([sPLOT, ePLOT])
plt.legend()
plt.grid()

# %% [markdown]
# ### Fill between 5, 25, 50, 75, 95 Percentile. Max and Min.

# %%
plt.fill_between(DATES, HTS['p25'], HTS['p75'], facecolor='grey', linewidth=0, label='p25-p75')
plt.fill_between(DATES, HTS['p75'], HTS['p95'], facecolor='lightgrey', linewidth=0, label='p05-p95')
plt.fill_between(DATES, HTS['p05'], HTS['p25'], facecolor='lightgrey', linewidth=0)
plt.plot(DATES, HTS['p50'], color='w', lw=.5, label='p50')
plt.plot(DATES, HTS['p100'], color='k', lw=.5, label='max, min')
plt.plot(DATES, HTS['p00'], color='k', lw=.5)

plt.title('Station: %s\nVariable: %s\nHours:%s' % (stn, var, hours))
plt.ylabel(ylabel)

plt.gca().xaxis.set_major_formatter(formatter)

if plot_MW:
    plt.plot(MW_DATES, a[MWvar], label='MesoWest', color='red', lw=3)

if plot_HRRR:
    plt.plot(HRRR_DATES, HRRR_val, color='orange', label='HRRR f00', lw=3.5)

plt.xlim([sPLOT, ePLOT])
plt.legend()
plt.grid()

# %% [markdown]
# ### Percentiles with Pollywogs

# %%
if plot_POLYWOG:
    # Start and End POLYwog plots
    sPOLY = datetime(2017, 10, 8)
    ePOLY = datetime(2017, 10, 10)

    # Station
    LD = get_MW_location_dict(stn)

    # Pollywog hours: a list of hours you want a pollywog to spawn
    pHours = range(0, 24, 6)

    # Head hours: a list of hours you want to plot a pollywog head (analysis value (f00))
    hHours = range(0, 24, 1)

    # Variable names for HRRR
    if var.split(':')[0] == 'UVGRD':
        HR_var = 'WIND:10 m'
    else:
        HR_var = var

    #=====================================================================

    # Create hourly range
    polyHOURS = (ePOLY-sPOLY).days * 24 + (ePOLY-sPOLY).seconds/3600
    polyDATES = np.array([sPOLY + timedelta(hours=x) for x in range(0, polyHOURS)])

    # Cycle pollywogs through these colors.
    colors = ['red', 'royalblue', 'green', 'darkorange'] * 50

    color_count = 0

# %%
if plot_POLYWOG:
    # Plot percentile shading
    plt.fill_between(DATES, HTS['p25'], HTS['p75'], facecolor='grey', linewidth=0, label='p25-p75')
    plt.fill_between(DATES, HTS['p75'], HTS['p95'], facecolor='lightgrey', linewidth=0, label='p05-p95')
    plt.fill_between(DATES, HTS['p05'], HTS['p25'], facecolor='lightgrey', linewidth=0)
    plt.plot(DATES, HTS['p50'], color='k', lw=.5, label='min, p50, max')
    plt.plot(DATES, HTS['p100'], color='k', lw=.5)
    plt.plot(DATES, HTS['p00'], color='k', lw=.5)

    plt.title('Station: %s\nVariable: %s\nHours:%s' % (stn, var, hours))
    plt.ylabel(ylabel)

    plt.gca().xaxis.set_major_formatter(formatter)

    if plot_MW:
        plt.plot(MW_DATES, a[MWvar], label='MesoWest', color='k', lw=3, ls='--')

    plt.xlim([sPLOT, ePLOT])
    if var.split(':')[0] == 'UVGRD':
        plt.ylim(ymin=0)
    plt.legend()
    plt.grid()

    # Plot each pollywog head and tail
    for D in polyDATES:
        if D.hour in pHours:
            # Get full pollywog for each hour requested
            P = get_hrrr_pollywog_multi(D, HR_var, LD, verbose=False); print 'Got pollywog', D

            # Convert units if necessary
            if MWvar == 'air_temp':
                P_value = P[stn]-273.15
            if MWvar == 'sea_level_pressure':
                P_value = P[stn]/100
            else:
                P_value = P[stn]

            # Convert dates to leap year
            P['DATETIME'] = [datetime(2016, DD.month, DD.day, DD.hour) for DD in P['DATETIME']]

            # Plot the HRRR pollywog
            # Head
            plt.scatter(P['DATETIME'][0], P_value[0], c=colors[color_count], s=130, lw=0, zorder=2)
            # Tail
            plt.plot(P['DATETIME'], P_value, c=colors[color_count], lw=3, zorder=2)
            color_count += 1

        if D.hour in hHours:
            # Plot the HRRR data point grey. Have to redownload P just in case it doesn't exist already
            P = get_hrrr_pollywog_multi(D, HR_var, LD, forecast_limit=0, verbose=False); print "got head", D

            # Convert dates to leap year
            P['DATETIME'] = [datetime(2016, DD.month, DD.day, DD.hour) for DD in P['DATETIME']]

            # Convert units if necessary
            if MWvar == 'air_temp':
                P_value = P[stn]-273.15
            if MWvar == 'sea_level_pressure':
                P_value = P[stn]/100
            else:
                P_value = P[stn]
            plt.scatter(P['DATETIME'][0], P_value[0], c=[.2, .2, .2], s=50, lw=0, zorder=3)
    plt.grid()
    plt.savefig('./figs/HOVEMOLLER_%s_%s-%s' % (stn, sDATE.strftime('%Y%m%d'), eDATE.strftime('%Y%m%d')))
# Out:
# Got pollywog 2017-10-08 00:00:00
# got head 2017-10-08 00:00:00
# got head 2017-10-08 01:00:00
# got head 2017-10-08 02:00:00
# got head 2017-10-08 03:00:00
# got head 2017-10-08 04:00:00
# got head 2017-10-08 05:00:00
# Got pollywog 2017-10-08 06:00:00
# got head 2017-10-08 06:00:00
# got head 2017-10-08 07:00:00
# got head 2017-10-08 08:00:00
# got head 2017-10-08 09:00:00
# got head 2017-10-08 10:00:00
# got head 2017-10-08 11:00:00
# Got pollywog 2017-10-08 12:00:00
# got head 2017-10-08 12:00:00
# got head 2017-10-08 13:00:00
# got head 2017-10-08 14:00:00
# got head 2017-10-08 15:00:00
# got head 2017-10-08 16:00:00
# got head 2017-10-08 17:00:00
# Got pollywog 2017-10-08 18:00:00
# got head 2017-10-08 18:00:00
# got head 2017-10-08 19:00:00
# got head 2017-10-08 20:00:00
# got head 2017-10-08 21:00:00
# got head 2017-10-08 22:00:00
# got head 2017-10-08 23:00:00
# Got pollywog 2017-10-09 00:00:00
# got head 2017-10-09 00:00:00
# got head 2017-10-09 01:00:00
# got head 2017-10-09 02:00:00
# got head 2017-10-09 03:00:00
# got head 2017-10-09 04:00:00
# got head 2017-10-09 05:00:00
# Got pollywog 2017-10-09 06:00:00
# got head 2017-10-09 06:00:00
# got head 2017-10-09 07:00:00
# got head 2017-10-09 08:00:00
# got head 2017-10-09 09:00:00
# got head 2017-10-09 10:00:00
# got head 2017-10-09 11:00:00
# Got pollywog 2017-10-09 12:00:00
# got head 2017-10-09 12:00:00
# got head 2017-10-09 13:00:00
# got head 2017-10-09 14:00:00
# got head 2017-10-09 15:00:00
# got head 2017-10-09 16:00:00
# got head 2017-10-09 17:00:00
# Got pollywog 2017-10-09 18:00:00
# got head 2017-10-09 18:00:00
# got head 2017-10-09 19:00:00
# got head 2017-10-09 20:00:00
# got head 2017-10-09 21:00:00
# got head 2017-10-09 22:00:00
# got head 2017-10-09 23:00:00

# %%
plt.savefig('./figs/HOVEMOLLER_%s_%s-%s' % (stn, sDATE.strftime('%Y%m%d'), eDATE.strftime('%Y%m%d')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-98180d342fcf> in <module>()
# ----> 1 plt.gca().savefig('./figs/HOVEMOLLER_%s_%s-%s' % (stn, sDATE.strftime('%Y%m%d'), eDATE.strftime('%Y%m%d')))
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %% [markdown]
# # MesoWest Percentiles

# %%
import json
import urllib2

start = sDATE.strftime('%m%d%H') # mmddhh
end = eDATE.strftime('%m%d%H')   # mmddhh
URL = 'http://dev2.mesowest.net:8089/percentiles?' \
    + '&token=demotoken' \
    + '&start=' + start \
    + '&end=' + end \
    + '&vars=' + MWvar \
    + '&stid=' + stn \
    + '&percentiles=' + '0,5,25,50,75,95,100'

print URL

f = urllib2.urlopen(URL)
data = f.read()
data = json.loads(data)
# Out:
# http://dev2.mesowest.net:8089/percentiles?&token=demotoken&start=010100&end=123100&vars=wind_speed&stid=WBB&percentiles=0,5,25,50,75,95,100

# %%
data.keys()
# Out:
# [u'UNITS', u'STATION', u'PERCENTILE_LIST', u'SUMMARY']

# %%
all_per = np.array(data['STATION'][0]['PERCENTILES']['%s_set_1' % MWvar])
p00 = all_per[:,0]
p05 = all_per[:,1]
p25 = all_per[:,2]
p50 = all_per[:,3]
p75 = all_per[:,4]
p95 = all_per[:,5]
p100 = all_per[:,6]

# %%
per_dates = np.array(data['STATION'][0]['PERCENTILES']['date_time'])
MW_DATES = np.array([datetime(2016, int(d[0:2]), int(d[2:4]), int(d[4:6])) for d in per_dates])

# %%
len(MW_DATES)
# Out:
# 8761

# %%
plt.fill_between(DATES, HTS['p25'], HTS['p75'], facecolor='grey', linewidth=0, label='p25-p75')
plt.fill_between(DATES, HTS['p75'], HTS['p95'], facecolor='lightgrey', linewidth=0, label='p05-p95')
plt.fill_between(DATES, HTS['p05'], HTS['p25'], facecolor='lightgrey', linewidth=0)
plt.plot(DATES, HTS['p50'], color='w', lw=.5, label='p50')
plt.plot(DATES, HTS['p100'], color='k', lw=.5, label='max, min')
plt.plot(DATES, HTS['p00'], color='k', lw=.5)

plt.ylabel(ylabel)

plt.gca().xaxis.set_major_formatter(formatter)

if plot_MW:
    plt.plot(MW_DATES, a[MWvar], label='MesoWest', color='red', lw=3)

if plot_HRRR:
    plt.plot(HRRR_DATES, HRRR_val, color='orange', label='HRRR f00', lw=3.5)

plt.xlim([sPLOT, ePLOT])
plt.legend()
plt.grid()

if len(hours) == 1:
    # hour of day to plot
    hh = hours[0]
    # plot every nth hour (use 1 for every hour, use 24 for every day)
    nth = 24
else:
    hh = hours[0]
    nth = 24/len(hours)
    
#plt.plot(MW_DATES[range(hh, len(MW_DATES), nth)], p00[range(hh, len(MW_DATES), nth)], label='p00')
plt.plot(MW_DATES[range(hh, len(MW_DATES), nth)], p05[range(hh, len(MW_DATES), nth)],
         label='MW p05',
         lw=3)
plt.plot(MW_DATES[range(hh, len(MW_DATES), nth)], p50[range(hh, len(MW_DATES), nth)],
         label='MW p50',
         lw=3)
plt.plot(MW_DATES[range(hh, len(MW_DATES), nth)], p95[range(hh, len(MW_DATES), nth)],
         label='MW p95',
         lw=3)
#plt.plot(MW_DATES[range(hh, len(MW_DATES), nth)], p100[range(hh, len(MW_DATES), nth)], label='p100')

#plt.title('MESOWEST PERCENTILES Station: %s\nVariable: %s\nHours:%s' % (stn, var, hours))


plt.gca().xaxis.set_major_formatter(formatter)

if plot_MW:
    plt.plot(MW_DATES, a[MWvar], label='MesoWest', color='k', lw=0.4)

plt.xlim([sPLOT, ePLOT])
plt.legend()
plt.grid()
plt.savefig('./figs/TS_%s_%s_p05p50p95_h%02d_realMW' % (stn, var.replace(':', '').replace(' ', ''), hours[0]))
plt.grid()

# %%
# Out:
# array([datetime.datetime(2016, 1, 1, 18, 0),
#        datetime.datetime(2016, 1, 2, 18, 0),
#        datetime.datetime(2016, 1, 3, 18, 0),
#        datetime.datetime(2016, 1, 4, 18, 0),
#        datetime.datetime(2016, 1, 5, 18, 0),
#        datetime.datetime(2016, 1, 6, 18, 0),
#        datetime.datetime(2016, 1, 7, 18, 0),
#        datetime.datetime(2016, 1, 8, 18, 0),
#        datetime.datetime(2016, 1, 9, 18, 0),
#        datetime.datetime(2016, 1, 10, 18, 0),
#        datetime.datetime(2016, 1, 11, 18, 0),
#        datetime.datetime(2016, 1, 12, 18, 0),
#        datetime.datetime(2016, 1, 13, 18, 0),
#        datetime.datetime(2016, 1, 14, 18, 0),
#        datetime.datetime(2016, 1, 15, 18, 0),
#        datetime.datetime(2016, 1, 16, 18, 0),
#        datetime.datetime(2016, 1, 17, 18, 0),
#        datetime.datetime(2016, 1, 18, 18, 0),
#        datetime.datetime(2016, 1, 19, 18, 0),
#        datetime.datetime(2016, 1, 20, 18, 0),
#        datetime.datetime(2016, 1, 21, 18, 0),
#        datetime.datetime(2016, 1, 22, 18, 0),
#        datetime.datetime(2016, 1, 23, 18, 0),
#        datetime.datetime(2016, 1, 24, 18, 0),
#        datetime.datetime(2016, 1, 25, 18, 0),
#        datetime.datetime(2016, 1, 26, 18, 0),
#        datetime.datetime(2016, 1, 27, 18, 0),
#        datetime.datetime(2016, 1, 28, 18, 0),
#        datetime.datetime(2016, 1, 29, 18, 0),
#        datetime.datetime(2016, 1, 30, 18, 0),
#        datetime.datetime(2016, 1, 31, 18, 0),
#        datetime.datetime(2016, 2, 1, 18, 0),
#        datetime.datetime(2016, 2, 2, 18, 0),
#        datetime.datetime(2016, 2, 3, 18, 0),
#        datetime.datetime(2016, 2, 4, 18, 0),
#        datetime.datetime(2016, 2, 5, 18, 0),
#        datetime.datetime(2016, 2, 6, 18, 0),
#        datetime.datetime(2016, 2, 7, 18, 0),
#        datetime.datetime(2016, 2, 8, 18, 0),
#        datetime.datetime(2016, 2, 9, 18, 0),
#        datetime.datetime(2016, 2, 10, 18, 0),
#        datetime.datetime(2016, 2, 11, 18, 0),
#        datetime.datetime(2016, 2, 12, 18, 0),
#        datetime.datetime(2016, 2, 13, 18, 0),
#        datetime.datetime(2016, 2, 14, 18, 0),
#        datetime.datetime(2016, 2, 15, 18, 0),
#        datetime.datetime(2016, 2, 16, 18, 0),
#        datetime.datetime(2016, 2, 17, 18, 0),
#        datetime.datetime(2016, 2, 18, 18, 0),
#        datetime.datetime(2016, 2, 19, 18, 0),
#        datetime.datetime(2016, 2, 20, 18, 0),
#        datetime.datetime(2016, 2, 21, 18, 0),
#        datetime.datetime(2016, 2, 22, 18, 0),
#        datetime.datetime(2016, 2, 23, 18, 0),
#        datetime.datetime(2016, 2, 24, 18, 0),
#        datetime.datetime(2016, 2, 25, 18, 0),
#        datetime.datetime(2016, 2, 26, 18, 0),
#        datetime.datetime(2016, 2, 27, 18, 0),
#        datetime.datetime(2016, 2, 28, 18, 0),
#        datetime.datetime(2016, 2, 29, 18, 0),
#        datetime.datetime(2016, 3, 1, 18, 0),
#        datetime.datetime(2016, 3, 2, 18, 0),
#        datetime.datetime(2016, 3, 3, 18, 0),
#        datetime.datetime(2016, 3, 4, 18, 0),
#        datetime.datetime(2016, 3, 5, 18, 0),
#        datetime.datetime(2016, 3, 6, 18, 0),
#        datetime.datetime(2016, 3, 7, 18, 0),
#        datetime.datetime(2016, 3, 8, 18, 0),
#        datetime.datetime(2016, 3, 9, 18, 0),
#        datetime.datetime(2016, 3, 10, 18, 0),
#        datetime.datetime(2016, 3, 11, 18, 0),
#        datetime.datetime(2016, 3, 12, 18, 0),
#        datetime.datetime(2016, 3, 13, 18, 0),
#        datetime.datetime(2016, 3, 14, 18, 0),
#        datetime.datetime(2016, 3, 15, 18, 0),
#        datetime.datetime(2016, 3, 16, 18, 0),
#        datetime.datetime(2016, 3, 17, 18, 0),
#        datetime.datetime(2016, 3, 18, 18, 0),
#        datetime.datetime(2016, 3, 19, 18, 0),
#        datetime.datetime(2016, 3, 20, 18, 0),
#        datetime.datetime(2016, 3, 21, 18, 0),
#        datetime.datetime(2016, 3, 22, 18, 0),
#        datetime.datetime(2016, 3, 23, 18, 0),
#        datetime.datetime(2016, 3, 24, 18, 0),
#        datetime.datetime(2016, 3, 25, 18, 0),
#        datetime.datetime(2016, 3, 26, 18, 0),
#        datetime.datetime(2016, 3, 27, 18, 0),
#        datetime.datetime(2016, 3, 28, 18, 0),
#        datetime.datetime(2016, 3, 29, 18, 0),
#        datetime.datetime(2016, 3, 30, 18, 0),
#        datetime.datetime(2016, 3, 31, 18, 0),
#        datetime.datetime(2016, 4, 1, 18, 0),
#        datetime.datetime(2016, 4, 2, 18, 0),
#        datetime.datetime(2016, 4, 3, 18, 0),
#        datetime.datetime(2016, 4, 4, 18, 0),
#        datetime.datetime(2016, 4, 5, 18, 0),
#        datetime.datetime(2016, 4, 6, 18, 0),
#        datetime.datetime(2016, 4, 7, 18, 0),
#        datetime.datetime(2016, 4, 8, 18, 0),
#        datetime.datetime(2016, 4, 9, 18, 0),
#        datetime.datetime(2016, 4, 10, 18, 0),
#        datetime.datetime(2016, 4, 11, 18, 0),
#        datetime.datetime(2016, 4, 12, 18, 0),
#        datetime.datetime(2016, 4, 13, 18, 0),
#        datetime.datetime(2016, 4, 14, 18, 0),
#        datetime.datetime(2016, 4, 15, 18, 0),
#        datetime.datetime(2016, 4, 16, 18, 0),
#        datetime.datetime(2016, 4, 17, 18, 0),
#        datetime.datetime(2016, 4, 18, 18, 0),
#        datetime.datetime(2016, 4, 19, 18, 0),
#        datetime.datetime(2016, 4, 20, 18, 0),
#        datetime.datetime(2016, 4, 21, 18, 0),
#        datetime.datetime(2016, 4, 22, 18, 0),
#        datetime.datetime(2016, 4, 23, 18, 0),
#        datetime.datetime(2016, 4, 24, 18, 0),
#        datetime.datetime(2016, 4, 25, 18, 0),
#        datetime.datetime(2016, 4, 26, 18, 0),
#        datetime.datetime(2016, 4, 27, 18, 0),
#        datetime.datetime(2016, 4, 28, 18, 0),
#        datetime.datetime(2016, 4, 29, 18, 0),
#        datetime.datetime(2016, 4, 30, 18, 0),
#        datetime.datetime(2016, 5, 1, 18, 0),
#        datetime.datetime(2016, 5, 2, 18, 0),
#        datetime.datetime(2016, 5, 3, 18, 0),
#        datetime.datetime(2016, 5, 4, 18, 0),
#        datetime.datetime(2016, 5, 5, 18, 0),
#        datetime.datetime(2016, 5, 6, 18, 0),
#        datetime.datetime(2016, 5, 7, 18, 0),
#        datetime.datetime(2016, 5, 8, 18, 0),
#        datetime.datetime(2016, 5, 9, 18, 0),
#        datetime.datetime(2016, 5, 10, 18, 0),
#        datetime.datetime(2016, 5, 11, 18, 0),
#        datetime.datetime(2016, 5, 12, 18, 0),
#        datetime.datetime(2016, 5, 13, 18, 0),
#        datetime.datetime(2016, 5, 14, 18, 0),
#        datetime.datetime(2016, 5, 15, 18, 0),
#        datetime.datetime(2016, 5, 16, 18, 0),
#        datetime.datetime(2016, 5, 17, 18, 0),
#        datetime.datetime(2016, 5, 18, 18, 0),
#        datetime.datetime(2016, 5, 19, 18, 0),
#        datetime.datetime(2016, 5, 20, 18, 0),
#        datetime.datetime(2016, 5, 21, 18, 0),
#        datetime.datetime(2016, 5, 22, 18, 0),
#        datetime.datetime(2016, 5, 23, 18, 0),
#        datetime.datetime(2016, 5, 24, 18, 0),
#        datetime.datetime(2016, 5, 25, 18, 0),
#        datetime.datetime(2016, 5, 26, 18, 0),
#        datetime.datetime(2016, 5, 27, 18, 0),
#        datetime.datetime(2016, 5, 28, 18, 0),
#        datetime.datetime(2016, 5, 29, 18, 0),
#        datetime.datetime(2016, 5, 30, 18, 0),
#        datetime.datetime(2016, 5, 31, 18, 0),
#        datetime.datetime(2016, 6, 1, 18, 0),
#        datetime.datetime(2016, 6, 2, 18, 0),
#        datetime.datetime(2016, 6, 3, 18, 0),
#        datetime.datetime(2016, 6, 4, 18, 0),
#        datetime.datetime(2016, 6, 5, 18, 0),
#        datetime.datetime(2016, 6, 6, 18, 0),
#        datetime.datetime(2016, 6, 7, 18, 0),
#        datetime.datetime(2016, 6, 8, 18, 0),
#        datetime.datetime(2016, 6, 9, 18, 0),
#        datetime.datetime(2016, 6, 10, 18, 0),
#        datetime.datetime(2016, 6, 11, 18, 0),
#        datetime.datetime(2016, 6, 12, 18, 0),
#        datetime.datetime(2016, 6, 13, 18, 0),
#        datetime.datetime(2016, 6, 14, 18, 0),
#        datetime.datetime(2016, 6, 15, 18, 0),
#        datetime.datetime(2016, 6, 16, 18, 0),
#        datetime.datetime(2016, 6, 17, 18, 0),
#        datetime.datetime(2016, 6, 18, 18, 0),
#        datetime.datetime(2016, 6, 19, 18, 0),
#        datetime.datetime(2016, 6, 20, 18, 0),
#        datetime.datetime(2016, 6, 21, 18, 0),
#        datetime.datetime(2016, 6, 22, 18, 0),
#        datetime.datetime(2016, 6, 23, 18, 0),
#        datetime.datetime(2016, 6, 24, 18, 0),
#        datetime.datetime(2016, 6, 25, 18, 0),
#        datetime.datetime(2016, 6, 26, 18, 0),
#        datetime.datetime(2016, 6, 27, 18, 0),
#        datetime.datetime(2016, 6, 28, 18, 0),
#        datetime.datetime(2016, 6, 29, 18, 0),
#        datetime.datetime(2016, 6, 30, 18, 0),
#        datetime.datetime(2016, 7, 1, 18, 0),
#        datetime.datetime(2016, 7, 2, 18, 0),
#        datetime.datetime(2016, 7, 3, 18, 0),
#        datetime.datetime(2016, 7, 4, 18, 0),
#        datetime.datetime(2016, 7, 5, 18, 0),
#        datetime.datetime(2016, 7, 6, 18, 0),
#        datetime.datetime(2016, 7, 7, 18, 0),
#        datetime.datetime(2016, 7, 8, 18, 0),
#        datetime.datetime(2016, 7, 9, 18, 0),
#        datetime.datetime(2016, 7, 10, 18, 0),
#        datetime.datetime(2016, 7, 11, 18, 0),
#        datetime.datetime(2016, 7, 12, 18, 0),
#        datetime.datetime(2016, 7, 13, 18, 0),
#        datetime.datetime(2016, 7, 14, 18, 0),
#        datetime.datetime(2016, 7, 15, 18, 0),
#        datetime.datetime(2016, 7, 16, 18, 0),
#        datetime.datetime(2016, 7, 17, 18, 0),
#        datetime.datetime(2016, 7, 18, 18, 0),
#        datetime.datetime(2016, 7, 19, 18, 0),
#        datetime.datetime(2016, 7, 20, 18, 0),
#        datetime.datetime(2016, 7, 21, 18, 0),
#        datetime.datetime(2016, 7, 22, 18, 0),
#        datetime.datetime(2016, 7, 23, 18, 0),
#        datetime.datetime(2016, 7, 24, 18, 0),
#        datetime.datetime(2016, 7, 25, 18, 0),
#        datetime.datetime(2016, 7, 26, 18, 0),
#        datetime.datetime(2016, 7, 27, 18, 0),
#        datetime.datetime(2016, 7, 28, 18, 0),
#        datetime.datetime(2016, 7, 29, 18, 0),
#        datetime.datetime(2016, 7, 30, 18, 0),
#        datetime.datetime(2016, 7, 31, 18, 0),
#        datetime.datetime(2016, 8, 1, 18, 0),
#        datetime.datetime(2016, 8, 2, 18, 0),
#        datetime.datetime(2016, 8, 3, 18, 0),
#        datetime.datetime(2016, 8, 4, 18, 0),
#        datetime.datetime(2016, 8, 5, 18, 0),
#        datetime.datetime(2016, 8, 6, 18, 0),
#        datetime.datetime(2016, 8, 7, 18, 0),
#        datetime.datetime(2016, 8, 8, 18, 0),
#        datetime.datetime(2016, 8, 9, 18, 0),
#        datetime.datetime(2016, 8, 10, 18, 0),
#        datetime.datetime(2016, 8, 11, 18, 0),
#        datetime.datetime(2016, 8, 12, 18, 0),
#        datetime.datetime(2016, 8, 13, 18, 0),
#        datetime.datetime(2016, 8, 14, 18, 0),
#        datetime.datetime(2016, 8, 15, 18, 0),
#        datetime.datetime(2016, 8, 16, 18, 0),
#        datetime.datetime(2016, 8, 17, 18, 0),
#        datetime.datetime(2016, 8, 18, 18, 0),
#        datetime.datetime(2016, 8, 19, 18, 0),
#        datetime.datetime(2016, 8, 20, 18, 0),
#        datetime.datetime(2016, 8, 21, 18, 0),
#        datetime.datetime(2016, 8, 22, 18, 0),
#        datetime.datetime(2016, 8, 23, 18, 0),
#        datetime.datetime(2016, 8, 24, 18, 0),
#        datetime.datetime(2016, 8, 25, 18, 0),
#        datetime.datetime(2016, 8, 26, 18, 0),
#        datetime.datetime(2016, 8, 27, 18, 0),
#        datetime.datetime(2016, 8, 28, 18, 0),
#        datetime.datetime(2016, 8, 29, 18, 0),
#        datetime.datetime(2016, 8, 30, 18, 0),
#        datetime.datetime(2016, 8, 31, 18, 0),
#        datetime.datetime(2016, 9, 1, 18, 0),
#        datetime.datetime(2016, 9, 2, 18, 0),
#        datetime.datetime(2016, 9, 3, 18, 0),
#        datetime.datetime(2016, 9, 4, 18, 0),
#        datetime.datetime(2016, 9, 5, 18, 0),
#        datetime.datetime(2016, 9, 6, 18, 0),
#        datetime.datetime(2016, 9, 7, 18, 0),
#        datetime.datetime(2016, 9, 8, 18, 0),
#        datetime.datetime(2016, 9, 9, 18, 0),
#        datetime.datetime(2016, 9, 10, 18, 0),
#        datetime.datetime(2016, 9, 11, 18, 0),
#        datetime.datetime(2016, 9, 12, 18, 0),
#        datetime.datetime(2016, 9, 13, 18, 0),
#        datetime.datetime(2016, 9, 14, 18, 0),
#        datetime.datetime(2016, 9, 15, 18, 0),
#        datetime.datetime(2016, 9, 16, 18, 0),
#        datetime.datetime(2016, 9, 17, 18, 0),
#        datetime.datetime(2016, 9, 18, 18, 0),
#        datetime.datetime(2016, 9, 19, 18, 0),
#        datetime.datetime(2016, 9, 20, 18, 0),
#        datetime.datetime(2016, 9, 21, 18, 0),
#        datetime.datetime(2016, 9, 22, 18, 0),
#        datetime.datetime(2016, 9, 23, 18, 0),
#        datetime.datetime(2016, 9, 24, 18, 0),
#        datetime.datetime(2016, 9, 25, 18, 0),
#        datetime.datetime(2016, 9, 26, 18, 0),
#        datetime.datetime(2016, 9, 27, 18, 0),
#        datetime.datetime(2016, 9, 28, 18, 0),
#        datetime.datetime(2016, 9, 29, 18, 0),
#        datetime.datetime(2016, 9, 30, 18, 0),
#        datetime.datetime(2016, 10, 1, 18, 0),
#        datetime.datetime(2016, 10, 2, 18, 0),
#        datetime.datetime(2016, 10, 3, 18, 0),
#        datetime.datetime(2016, 10, 4, 18, 0),
#        datetime.datetime(2016, 10, 5, 18, 0),
#        datetime.datetime(2016, 10, 6, 18, 0),
#        datetime.datetime(2016, 10, 7, 18, 0),
#        datetime.datetime(2016, 10, 8, 18, 0),
#        datetime.datetime(2016, 10, 9, 18, 0),
#        datetime.datetime(2016, 10, 10, 18, 0),
#        datetime.datetime(2016, 10, 11, 18, 0),
#        datetime.datetime(2016, 10, 12, 18, 0),
#        datetime.datetime(2016, 10, 13, 18, 0),
#        datetime.datetime(2016, 10, 14, 18, 0),
#        datetime.datetime(2016, 10, 15, 18, 0),
#        datetime.datetime(2016, 10, 16, 18, 0),
#        datetime.datetime(2016, 10, 17, 18, 0),
#        datetime.datetime(2016, 10, 18, 18, 0),
#        datetime.datetime(2016, 10, 19, 18, 0),
#        datetime.datetime(2016, 10, 20, 18, 0),
#        datetime.datetime(2016, 10, 21, 18, 0),
#        datetime.datetime(2016, 10, 22, 18, 0),
#        datetime.datetime(2016, 10, 23, 18, 0),
#        datetime.datetime(2016, 10, 24, 18, 0),
#        datetime.datetime(2016, 10, 25, 18, 0),
#        datetime.datetime(2016, 10, 26, 18, 0),
#        datetime.datetime(2016, 10, 27, 18, 0),
#        datetime.datetime(2016, 10, 28, 18, 0),
#        datetime.datetime(2016, 10, 29, 18, 0),
#        datetime.datetime(2016, 10, 30, 18, 0),
#        datetime.datetime(2016, 10, 31, 18, 0),
#        datetime.datetime(2016, 11, 1, 18, 0),
#        datetime.datetime(2016, 11, 2, 18, 0),
#        datetime.datetime(2016, 11, 3, 18, 0),
#        datetime.datetime(2016, 11, 4, 18, 0),
#        datetime.datetime(2016, 11, 5, 18, 0),
#        datetime.datetime(2016, 11, 6, 18, 0),
#        datetime.datetime(2016, 11, 7, 18, 0),
#        datetime.datetime(2016, 11, 8, 18, 0),
#        datetime.datetime(2016, 11, 9, 18, 0),
#        datetime.datetime(2016, 11, 10, 18, 0),
#        datetime.datetime(2016, 11, 11, 18, 0),
#        datetime.datetime(2016, 11, 12, 18, 0),
#        datetime.datetime(2016, 11, 13, 18, 0),
#        datetime.datetime(2016, 11, 14, 18, 0),
#        datetime.datetime(2016, 11, 15, 18, 0),
#        datetime.datetime(2016, 11, 16, 18, 0),
#        datetime.datetime(2016, 11, 17, 18, 0),
#        datetime.datetime(2016, 11, 18, 18, 0),
#        datetime.datetime(2016, 11, 19, 18, 0),
#        datetime.datetime(2016, 11, 20, 18, 0),
#        datetime.datetime(2016, 11, 21, 18, 0),
#        datetime.datetime(2016, 11, 22, 18, 0),
#        datetime.datetime(2016, 11, 23, 18, 0),
#        datetime.datetime(2016, 11, 24, 18, 0),
#        datetime.datetime(2016, 11, 25, 18, 0),
#        datetime.datetime(2016, 11, 26, 18, 0),
#        datetime.datetime(2016, 11, 27, 18, 0),
#        datetime.datetime(2016, 11, 28, 18, 0),
#        datetime.datetime(2016, 11, 29, 18, 0),
#        datetime.datetime(2016, 11, 30, 18, 0),
#        datetime.datetime(2016, 12, 1, 18, 0),
#        datetime.datetime(2016, 12, 2, 18, 0),
#        datetime.datetime(2016, 12, 3, 18, 0),
#        datetime.datetime(2016, 12, 4, 18, 0),
#        datetime.datetime(2016, 12, 5, 18, 0),
#        datetime.datetime(2016, 12, 6, 18, 0),
#        datetime.datetime(2016, 12, 7, 18, 0),
#        datetime.datetime(2016, 12, 8, 18, 0),
#        datetime.datetime(2016, 12, 9, 18, 0),
#        datetime.datetime(2016, 12, 10, 18, 0),
#        datetime.datetime(2016, 12, 11, 18, 0),
#        datetime.datetime(2016, 12, 12, 18, 0),
#        datetime.datetime(2016, 12, 13, 18, 0),
#        datetime.datetime(2016, 12, 14, 18, 0),
#        datetime.datetime(2016, 12, 15, 18, 0),
#        datetime.datetime(2016, 12, 16, 18, 0),
#        datetime.datetime(2016, 12, 17, 18, 0),
#        datetime.datetime(2016, 12, 18, 18, 0),
#        datetime.datetime(2016, 12, 19, 18, 0),
#        datetime.datetime(2016, 12, 20, 18, 0),
#        datetime.datetime(2016, 12, 21, 18, 0),
#        datetime.datetime(2016, 12, 22, 18, 0),
#        datetime.datetime(2016, 12, 23, 18, 0),
#        datetime.datetime(2016, 12, 24, 18, 0),
#        datetime.datetime(2016, 12, 25, 18, 0),
#        datetime.datetime(2016, 12, 26, 18, 0),
#        datetime.datetime(2016, 12, 27, 18, 0),
#        datetime.datetime(2016, 12, 28, 18, 0),
#        datetime.datetime(2016, 12, 29, 18, 0),
#        datetime.datetime(2016, 12, 30, 18, 0)], dtype=object)
