# %% [markdown]
# Brian Blaylock
# June 18, 2018
#
# # National Red Flag Conditions
# Compiled by Laura, summer 2018

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

import sys
sys.path.append('/uufs/chpc.utah.edu/common/home/u0553130/pyBKB_v2/')
from BB_basemap.draw_maps import draw_CONUS_HRRR_map
import pyshp.shapefile as shapefile

# %%
m = draw_CONUS_HRRR_map()

# %%
sf = shapefile.Reader('/uufs/chpc.utah.edu/common/home/u0553130/PhD/Red_Flag_Map/Red_Flag_exported')

# %%
shapes = sf.shapes()

# %%
for S in shapes:
    lons = []
    lats = []
    for i in S.points:
        lons.append(i[0])
        lats.append(i[1])
    m.plot(lons, lats, marker=None, color='m', latlon=True, linewidth=.3)

# %%
sf.fields
# Out:
# [('DeletionFlag', 'C', 1, 0),
#  ['STATE', 'C', 2, 0],
#  ['ZONE', 'C', 3, 0],
#  ['CWA', 'C', 9, 0],
#  ['NAME', 'C', 254, 0],
#  ['STATE_ZONE', 'C', 5, 0],
#  ['TIME_ZONE', 'C', 2, 0],
#  ['FE_AREA', 'C', 2, 0],
#  ['LON', 'N', 19, 11],
#  ['LAT', 'N', 19, 11],
#  ['SHORTNAME', 'C', 32, 0],
#  ["20' Winds", 'N', 10, 0],
#  ['RH (%)', 'N', 10, 0],
#  ['Wind Gust', 'N', 10, 0],
#  ['Temp.', 'N', 10, 0]]

# %%
sf.records()
# Out:
# [['GU',
#   '013',
#   'GUM',
#   'Kayangel',
#   'GU013',
#   'J',
#   '  ',
#   134.71288938,
#   8.07351501472,
#   'Kayangel',
#   16,
#   60,
#   999,
#   999],
#  ['GU',
#   '011',
#   'GUM',
#   'Koror',
#   'GU011',
#   'J',
#   '  ',
#   134.535068624,
#   7.44415566463,
#   'Koror',
#   16,
#   60,
#   999,
#   999],
#  ['GU',
#   '041',
#   'GUM',
#   'Pohnpei',
#   'GU041',
#   'F',
#   '  ',
#   158.225213036,
#   6.88066947461,
#   'Pohnpei',
#   16,
#   60,
#   999,
#   999],
#  ['GU',
#   '021',
#   'GUM',
#   'Yap',
#   'GU021',
#   'G',
#   '  ',
#   138.124444744,
#   9.53660268007,
#   'Yap',
#   16,
#   60,
#   999,
#   999],
#  ['GU',
#   '024',
#   'GUM',
#   'Sorol',
#   'GU024',
#   'G',
#   '  ',
#   140.697318765,
#   8.214289427,
#   'Sorol',
#   16,
#   60,
#   999,
#   999],
#  ['GU',
#   '022',
#   'GUM',
#   'Ngulu',
#   'GU022',
#   'G',
#   '  ',
#   137.507886929,
#   8.30217742926,
#   'Ngulu',
#   16,
#   60,
#   999,
#   999],
#  ['GU',
# ...
