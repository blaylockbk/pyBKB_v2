# %% [markdown]
# # Fires of Interest

# %%
# %matplotlib inline

import numpy as np
from datetime import date, datetime, timedelta

import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection

# %% [markdown]
# ## Dictionary of Fires of Interest

# %%
FIRES = {'PIONEER':{'lat': 43.950,
                    'lon': -115.762,
                    'start': datetime(2016, 7, 18),
                    'state': 'Idaho'},         
         'BRIANHEAD':{'lat': 37.718,
                      'lon': -112.837,
                      'start': datetime(2017, 6, 17),
                      'state': 'Utah'},
         'SOUTHERN LNU COMPLEX':{'lat': 38.296,
                                 'lon': -122.275,
                                 'start': datetime(2017, 10, 9),
                                 'state': 'California'},
         'CENTRAL LNU COMPLEX':{'lat': 38.433,
                                'lon': -122.703,
                                'start': datetime(2017, 10, 9),
                                'state': 'California'},
         'THOMAS':{'lat': 34.429,
                   'lon': -119.100,
                   'start': datetime(2017, 12, 5),
                   'satet': 'California'},
         'CREEK':{'lat': 34.334,
                  'lon': -118.338,
                  'start': datetime(2017, 12, 5),
                  'state': 'California'},
         'RYE':{'lat': 34.453,
                'lon': -118.581,
                'start': datetime(2017, 12, 5),
                'state': 'California'},
         }

# %% [markdown]
# ## Plot Fire Locations on a Map

# %%
lats = [FIRES[F]['lat'] for F in FIRES.keys()]
lons = [FIRES[F]['lon'] for F in FIRES.keys()]

bot_left_lat  = min(lats)-1.5
bot_left_lon  = min(lons)-1.5
top_right_lat = max(lats)+1.5
top_right_lon = max(lons)+1.5

m = Basemap(resolution='i', projection='cyl', area_thresh=1500,\
        llcrnrlon=bot_left_lon, llcrnrlat=bot_left_lat, \
        urcrnrlon=top_right_lon, urcrnrlat=top_right_lat)

# %%
m.arcgisimage(service='World_Shaded_Relief', dpi=1000)
m.drawstates(linewidth=.1)
m.drawcoastlines(linewidth=.15)
m.drawcountries(linewidth=.1)
#m.drawcounties()

plt.title('Fires of Interest')

for F in FIRES.keys():
    m.scatter(FIRES[F]['lon'], FIRES[F]['lat'])

# %% [markdown]
# ## Plot Fire Boundary via Shapefile
# Consult this demo page: http://basemaptutorial.readthedocs.io/en/latest/shapefile.html

# %%
# Specify a fire name
firename = 'THOMAS'

# Create a new map for this fire
bot_left_lat  = FIRES[firename]['lat']-.5
bot_left_lon  = FIRES[firename]['lon']-.5
top_right_lat = FIRES[firename]['lat']+.5
top_right_lon = FIRES[firename]['lon']+.5

m = Basemap(resolution='i', projection='cyl', area_thresh=1500,\
        llcrnrlon=bot_left_lon, llcrnrlat=bot_left_lat, \
        urcrnrlon=top_right_lon, urcrnrlat=top_right_lat)

# %%
# Read in the shape file. This takes some time if there are lots of objects
shapefile = '/uufs/chpc.utah.edu/common/home/u0553130/oper/HRRR_fires/perim'
per = m.readshapefile(shapefile, 'perim',
                      linewidth=.5,
                      color='dimgrey',
                      drawbounds=False)

# %% [markdown]
# Fire Perimeter by Latest Drawn Image

# %%
plt.figure(1, figsize=[5, 5])

# Shape by Fire Name and Last Date
recent_date = date(2010, 1, 1)

for i, [info, PERIM] in enumerate(zip(m.perim_info, m.perim)):
    # Check if the boundary is one of the large active fires
    if info['FIRENAME'].upper() == firename:
        f = info['PERDATTIME']
        draw_date = date(f[0], f[1], f[2])
        if draw_date > recent_date:
            patches = []
            recent_date = draw_date
            patches.append(Polygon(np.array(PERIM), True) )

plt.gca().add_collection(PatchCollection(patches,
                         facecolor='indianred',
                         alpha=.65,
                         edgecolor='k',
                         linewidths=1,
                         zorder=1))

m.arcgisimage(service='World_Shaded_Relief', dpi=1000)

# %% [markdown]
# Fire Perimeter by Largest Area

# %%
plt.figure(1, figsize=[5, 5])

# Shape by Fire Name and Largest Area
area = 0

for i, [info, PERIM] in enumerate(zip(m.perim_info, m.perim)):
    # Check if the boundary is one of the large active fires
    if info['FIRENAME'].upper() == firename:
        f = info['GISACRES']
        draw_area = float(f)
        if draw_area > area:
            patches = []
            area = draw_area
            patches.append(Polygon(np.array(PERIM), True) )

plt.gca().add_collection(PatchCollection(patches,
                         facecolor='indianred',
                         alpha=.65,
                         edgecolor='k',
                         linewidths=1,
                         zorder=1))

m.arcgisimage(service='World_Shaded_Relief', dpi=1000)

# %% [markdown]
# All shapes for the Fire Name

# %%
patches = []
for info, PERIM in zip(m.perim_info, m.perim):
    # Check if the boundary is one of the large active fires
    if info['FIRENAME'].upper() == firename:
        patches.append(Polygon(np.array(PERIM), True) )

plt.gca().add_collection(PatchCollection(patches[:],
                         facecolor='indianred',
                         alpha=.65,
                         edgecolor='k',
                         linewidths=1,
                         zorder=1))

m.arcgisimage(service='World_Shaded_Relief', dpi=1000)

# %%
info
# Out:
# {'ACTIVE': 'N',
#  'AGENCY': 'BLM',
#  'COMMENTS': 'BLM Nevada State Office AGOL',
#  'COMPFIRECD': '    ',
#  'COMPLEXNM': '                                                                                                    ',
#  'COMPPARID': '                                                  ',
#  'DATECRNT': [2017, 11, 6],
#  'FIRECODE': 'LGX2',
#  'FIRENAME': 'Red 2',
#  'FIRENUM': '020358',
#  'FIREYEAR': '2017',
#  'GISACRES': '6.51629004100e+001',
#  'INCIDENTID': '2017-NVBMD-020358',
#  'INCIWEBID': '          ',
#  'INCOMPLEX': 'N',
#  'IRWINID': '{7A9FE18B-CEE6-40A5-8032-4A5462A67B52}',
#  'MAPMETHOD': 'GPS-Driven',
#  'MERGEID': '{}',
#  'PERDATTIME': [2017, 10, 31],
#  'RINGNUM': 1,
#  'SHAPENUM': 6991,
#  'STATE': 'NV',
#  'UNITIDOWN': '       ',
#  'UNITIDPROT': 'NVBMD'}

# %%
for info, PERIM in zip(m.perim_info, m.perim):
    # Check if the boundary is one of the large active fires
    if info['FIRENAME'].upper() == firename:
        print info
# Out:
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 1, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 5], 'INCOMPLEX': 'N', 'GISACRES': '3.11818115848e+004', 'STATE': 'CA', 'ACTIVE': 'N', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Unknown', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6765, 'PERDATTIME': [2017, 12, 5]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 2, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 5], 'INCOMPLEX': 'N', 'GISACRES': '3.11818115848e+004', 'STATE': 'CA', 'ACTIVE': 'N', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Unknown', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6765, 'PERDATTIME': [2017, 12, 5]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 1, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 7], 'INCOMPLEX': 'N', 'GISACRES': '1.15824923535e+005', 'STATE': 'CA', 'ACTIVE': 'Y', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Infrared Image', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6807, 'PERDATTIME': [2017, 12, 6]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 2, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 7], 'INCOMPLEX': 'N', 'GISACRES': '1.15824923535e+005', 'STATE': 'CA', 'ACTIVE': 'Y', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Infrared Image', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6807, 'PERDATTIME': [2017, 12, 6]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 3, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 7], 'INCOMPLEX': 'N', 'GISACRES': '1.15824923535e+005', 'STATE': 'CA', 'ACTIVE': 'Y', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Infrared Image', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6807, 'PERDATTIME': [2017, 12, 6]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 4, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 7], 'INCOMPLEX': 'N', 'GISACRES': '1.15824923535e+005', 'STATE': 'CA', 'ACTIVE': 'Y', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Infrared Image', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6807, 'PERDATTIME': [2017, 12, 6]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 5, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 7], 'INCOMPLEX': 'N', 'GISACRES': '1.15824923535e+005', 'STATE': 'CA', 'ACTIVE': 'Y', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Infrared Image', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6807, 'PERDATTIME': [2017, 12, 6]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 6, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 7], 'INCOMPLEX': 'N', 'GISACRES': '1.15824923535e+005', 'STATE': 'CA', 'ACTIVE': 'Y', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Infrared Image', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6807, 'PERDATTIME': [2017, 12, 6]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 7, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 7], 'INCOMPLEX': 'N', 'GISACRES': '1.15824923535e+005', 'STATE': 'CA', 'ACTIVE': 'Y', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Infrared Image', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6807, 'PERDATTIME': [2017, 12, 6]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 8, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 7], 'INCOMPLEX': 'N', 'GISACRES': '1.15824923535e+005', 'STATE': 'CA', 'ACTIVE': 'Y', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Infrared Image', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6807, 'PERDATTIME': [2017, 12, 6]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 9, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 7], 'INCOMPLEX': 'N', 'GISACRES': '1.15824923535e+005', 'STATE': 'CA', 'ACTIVE': 'Y', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Infrared Image', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6807, 'PERDATTIME': [2017, 12, 6]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 1, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 7], 'INCOMPLEX': 'N', 'GISACRES': '9.62545023191e+004', 'STATE': 'CA', 'ACTIVE': 'N', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Hand Sketch', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6808, 'PERDATTIME': [2017, 12, 7]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 1, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 6], 'INCOMPLEX': 'N', 'GISACRES': '6.53689676255e+004', 'STATE': 'CA', 'ACTIVE': 'N', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Hand Sketch', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6888, 'PERDATTIME': [2017, 12, 6]}
# {'FIRENUM': '103156', 'COMPFIRECD': '    ', 'COMPLEXNM': '                                                                                                    ', 'COMPPARID': '                                                  ', 'UNITIDOWN': '       ', 'INCIDENTID': '2017-CAVNC-103156', 'MERGEID': '{}', 'FIREYEAR': '2017', 'INCIWEBID': '          ', 'RINGNUM': 2, 'FIRECODE': '    ', 'DATECRNT': [2017, 12, 6], 'INCOMPLEX': 'N', 'GISACRES': '6.53689676255e+004', 'STATE': 'CA', 'ACTIVE': 'N', 'FIRENAME': 'THOMAS', 'MAPMETHOD': 'Hand Sketch', 'UNITIDPROT': 'CAVNC', 'AGENCY': 'C&L', 'COMMENTS': '                                                                                                                                                                                                                                                              ', 'IRWINID': '{943D8086-7DF4-47C7-BB98-A358E962667E}', 'SHAPENUM': 6888, 'PERDATTIME': [2017, 12, 6]}

# %%
# Get active fire names and index fire perimeters
pp = 0
for info, f_per in zip(m.perim_info, m.perim):
    pp += 1
    if info['ACTIVE'] == 'Y':
        print info['FIRENAME'], pp
        np.array(f_per)
        for i in f_per:
            m.scatter(i[0], i[1])
    
m.drawstates()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-b61f3a421580> in <module>()
#       1 # Get active fire names and index fire perimeters
#       2 pp = 0
# ----> 3 for info, f_per in zip(m.perim_info, m.perim):
#       4     pp += 1
#       5     if info['ACTIVE'] == 'Y':
#
# AttributeError: 'Basemap' object has no attribute 'perim_info'

# %%
per_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-a6455917eb8e> in <module>()
# ----> 1 per_info
#
# NameError: name 'per_info' is not defined

# %%
m.perim_info
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-6601a28ec8d7> in <module>()
#       1
# ----> 2 m.perim_info
#
# AttributeError: 'Basemap' object has no attribute 'perim_info'
