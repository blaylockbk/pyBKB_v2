# %% [markdown]
# ##### Figure 7
# # Map of 10-m HRRR winds and MesoWest winds

# %%
# %matplotlib inline
import h5py
import matplotlib.pyplot as plt
import multiprocessing
import numpy as np
from mpl_toolkits.basemap import Basemap

import sys
sys.path.append('/uufs/chpc.utah.edu/common/home/u0553130/pyBKB_v2')
from BB_downloads.HRRR_S3 import *
from BB_MesoWest.MesoWest_STNinfo import get_MW_location_dict
from BB_MesoWest.MesoWest_nearesttime import get_mesowest_nearesttime
from BB_MesoWest.MesoWest_percentiles import get_mesowest_percentiles

# %%
from matplotlib.dates import DateFormatter
formatter = DateFormatter('%b')

import matplotlib as mpl 
two_column = 5.5
one_column = 3.2
twothird_column = 6.8
mpl.rcParams['figure.figsize'] = [twothird_column, twothird_column+5]
mpl.rcParams['figure.titlesize'] = 12
mpl.rcParams['figure.titleweight'] = 'bold'
mpl.rcParams['xtick.labelsize'] = 8
mpl.rcParams['ytick.labelsize'] = 8
mpl.rcParams['axes.labelsize'] = 8
mpl.rcParams['axes.titlesize'] = 10
mpl.rcParams['lines.linewidth'] = 1.8
mpl.rcParams['grid.linewidth'] = .25
mpl.rcParams['figure.subplot.wspace'] = 0.03
mpl.rcParams['figure.subplot.hspace'] = 0.05
mpl.rcParams['legend.fontsize'] = 7
mpl.rcParams['legend.framealpha'] = .75
mpl.rcParams['legend.loc'] = 'best'
mpl.rcParams['savefig.bbox'] = 'tight'
    
mpl.rcParams['savefig.dpi'] = 1000    # 600 for print

# %% [markdown]
# AMS Journal Figure size chart.
# _Note: Figsize parameter may differ from what is actually generated_
#
# | One Colulmn | 2/3 Page   | Two Columns   | More than 2 columns  |
# |---|---|---|---|
# | 3.2   | 4.5  | 5.5  | 6.5  |

# %% [markdown]
# ---

# %%
def get_OSG_point_percentiles(DATE, percentile=50):
    variable = var.replace(':', '_').replace(' ', '_')
    DIR = '/uufs/chpc.utah.edu/common/home/horel-group2/blaylock/HRRR_OSG/hourly30/%s/' % (variable)
    FILE = 'OSG_HRRR_%s_m%02d_d%02d_h%02d_f00.h5' % ((variable, DATE.month, DATE.day, DATE.hour))
    
    with h5py.File(DIR+FILE, 'r') as f:
        per_value = f["p%02d" % percentile][x][y]
    
    # Convert Units
    if var == 'TMP:2 m' or var == 'DPT:2 m':
        per_value -= 273.15
    
    return per_value

# %%
def get_OSG_percentiles(DATE, percentile=50):
    variable = var.replace(':', '_').replace(' ', '_')
    DIR = '/uufs/chpc.utah.edu/common/home/horel-group2/blaylock/HRRR_OSG/hourly30/%s/' % (variable)
    FILE = 'OSG_HRRR_%s_m%02d_d%02d_h%02d_f00.h5' % ((variable, DATE.month, DATE.day, DATE.hour))
    
    with h5py.File(DIR+FILE, 'r') as f:
        per_value = f["p%02d" % percentile][:]
    
    # Convert Units
    if var == 'TMP:2 m' or var == 'DPT:2 m':
        per_value -= 273.15
    
    return per_value

# %% [markdown]
# ---------

# %%
# Map Center Location, a MesoWest station ID
stn = 'HWKC1'
var = 'UVGRD:10 m'

# %%
# Get Lat/Lon Grid
DIR = '/uufs/chpc.utah.edu/common/home/horel-group7/Pando/hrrr/'
latlon_file = h5py.File(DIR+'HRRR_latlon.h5', 'r')
lat = latlon_file['latitude'].value
lon = latlon_file['longitude'].value

# %%
if var == 'TMP:2 m':
    MWvar = 'air_temp'
    label = '2 m Temperature'
    units = 'C'
    cmap = 'bwr'
elif var == 'DPT:2 m':
    MWvar = 'dew_point_temperature'
    label = '2 m Dew Point Temperature'
    units = 'C'
    cmap = 'BrBG'
elif var == 'UVGRD:10 m':
    MWvar = 'wind_speed'
    label = '10 m Wind Speed'
    units = r'm s$\mathregular{^{-1}}$'
    cmap = 'PiYG'
elif var == 'UVGRD:80 m':
    MWvar = 'wind_speed'
    label = '80 m Wind Speed'
    units = r'm s$\mathregular{^{-1}}$'
    cmap = 'PRGn'
else:
    MWvar = ''
    label = 'unknown'
    units = 'unknown'
    cmap = 'viridis'
    print "NO MATCHING VAR AND MESOWEST VAR"

# %%
# Percentile of interest
p=95

# %%
# Get list of stations in the area
from BB_MesoWest.get_token import my_token
import json

token = my_token()
URL = 'http://api.mesowest.net/v2/stations/metadata?&token=' + token + '&radius=HWKC1,45&vars=wind_speed'
if False:
    URL += '&network=1,2'
f = urllib2.urlopen(URL)
data_CA = f.read()
data_CA = json.loads(data_CA)

# %%
num = int(len(data_CA['STATION']))
print 'Number of Stations: %.f' % num
# Out:
# Number of Stations: 208

# %%
# Create a map centered at the station of interest: HWKC1
for s in data_CA['STATION']:
    if s['STID'] == stn:
        MWlon = float(s['LONGITUDE'])
        MWlat = float(s['LATITUDE'])

# Create Map Object
mapCenterLat = MWlat-.02
mapCenterLon = MWlon+.06
m = Basemap(projection='cyl', resolution='c', area_thresh=1000,
            llcrnrlon=mapCenterLon-.4,  urcrnrlon=mapCenterLon+.4,
            llcrnrlat=mapCenterLat-.4, urcrnrlat=mapCenterLat+.4)

# %%
m.drawcounties()
m.arcgisimage(service='World_Shaded_Relief', dpi=1000)

# %% [markdown]
# ### Retrieve Data

# %%
DATE = datetime(2017, 10, 9, 6)

# %%
start = DATE.strftime('%m%d%H')
end = start

stns_gt_3yrs = 0

for i, s in enumerate(data_CA['STATION']):
    print '\r>> %.2f%% complete. Working on %s' % (i/float(num)*100, s['STID']),
    sys.stdout.flush()
    
    # MesoWest percentile
    if 'PORTABLE' in s['NAME']:
        print " --> %s is a portable station. Skip it." % s['STID']
        continue
    else:
        try:
            a = get_mesowest_percentiles(s['STID'], variable=MWvar, start=start, end=end, percentiles=[p])
            if a['years'] >= 3:
                stns_gt_3yrs += 1
                MW_per = a['p%02d' % p][0]
                s['MW_per'] = MW_per

                # HRRR percentile
                MWlat = float(s['LATITUDE'])
                MWlon = float(s['LONGITUDE'])
                x, y = pluck_hrrr_point({'lat':lat,'lon':lon}, lat=MWlat, lon=MWlon,
                                        XY_only=True,
                                        verbose=False)
                HR_per = get_OSG_point_percentiles(DATE, percentile=p)
                s['HR_per'] = HR_per
                s['years'] = a['years']
        except:
            pass

print '\r>> Data retrieval 100% complete.',
print "# stations with more than three years:", stns_gt_3yrs
# Out:
# >> 5.77% complete. Working on BNRC1 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=BNRC1&percentiles=95&psource=PERCENTILES2
# >> 6.25% complete. Working on KSYC1 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=KSYC1&percentiles=95&psource=PERCENTILES2
# >> 6.73% complete. Working on LKEC1 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=LKEC1&percentiles=95&psource=PERCENTILES2
# >> 7.69% complete. Working on SCVC1 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=SCVC1&percentiles=95&psource=PERCENTILES2
# >> 8.65% complete. Working on TR102  --> TR102 is a portable station. Skip it.
# >> 9.13% complete. Working on TR110  --> TR110 is a portable station. Skip it.
# >> 10.10% complete. Working on TR163  --> TR163 is a portable station. Skip it.
# >> 10.58% complete. Working on TR164  --> TR164 is a portable station. Skip it.
# >> 11.06% complete. Working on TR417  --> TR417 is a portable station. Skip it.
# >> 12.50% complete. Working on C0211 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=C0211&percentiles=95&psource=PERCENTILES2
# >> 17.79% complete. Working on C1655 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=C1655&percentiles=95&psource=PERCENTILES2
# >> 19.71% complete. Working on C2038 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=C2038&percentiles=95&psource=PERCENTILES2
# >> 20.19% complete. Working on H0197 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=H0197&percentiles=95&psource=PERCENTILES2
# >> 23.08% complete. Working on C2908 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=C2908&percentiles=95&psource=PERCENTILES2
# >> 23.56% complete. Working on TS378  --> TS378 is a portable station. Skip it.
# >> 24.04% complete. Working on TS392  --> TS392 is a portable station. Skip it.
# >> 27.40% complete. Working on AR798 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=AR798&percentiles=95&psource=PERCENTILES2
# >> 27.88% complete. Working on C3741 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=C3741&percentiles=95&psource=PERCENTILES2
# >> 29.81% complete. Working on C4092 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=C4092&percentiles=95&psource=PERCENTILES2
# >> 30.77% complete. Working on C4081 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=C4081&percentiles=95&psource=PERCENTILES2
# >> 31.25% complete. Working on C4895 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=C4895&percentiles=95&psource=PERCENTILES2
# >> 33.17% complete. Working on C5813 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=C5813&percentiles=95&psource=PERCENTILES2
# >> 35.58% complete. Working on C6708 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=C6708&percentiles=95&psource=PERCENTILES2
# >> 37.50% complete. Working on C9603 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=C9603&percentiles=95&psource=PERCENTILES2
# >> 41.35% complete. Working on D2237 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=D2237&percentiles=95&psource=PERCENTILES2
# >> 42.79% complete. Working on D2696 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=D2696&percentiles=95&psource=PERCENTILES2
# >> 48.56% complete. Working on D6187 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=D6187&percentiles=95&psource=PERCENTILES2
# >> 49.04% complete. Working on D6382 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=D6382&percentiles=95&psource=PERCENTILES2
# >> 51.92% complete. Working on CQ213 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=CQ213&percentiles=95&psource=PERCENTILES2
# >> 61.54% complete. Working on E1188 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=E1188&percentiles=95&psource=PERCENTILES2
# >> 64.42% complete. Working on A1161 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=A1161&percentiles=95&psource=PERCENTILES2
# >> 66.83% complete. Working on UCMC DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=UCMC&percentiles=95&psource=PERCENTILES2
# >> 75.48% complete. Working on E7241 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=E7241&percentiles=95&psource=PERCENTILES2
# >> 79.33% complete. Working on HDNCA DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=HDNCA&percentiles=95&psource=PERCENTILES2
# >> 79.81% complete. Working on HOPCA DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=HOPCA&percentiles=95&psource=PERCENTILES2
# >> 80.29% complete. Working on KLGCA DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=KLGCA&percentiles=95&psource=PERCENTILES2
# >> 80.77% complete. Working on LVECA DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=LVECA&percentiles=95&psource=PERCENTILES2
# >> 81.25% complete. Working on MDTCA DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=MDTCA&percentiles=95&psource=PERCENTILES2
# >> 81.73% complete. Working on OCLCA DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=OCLCA&percentiles=95&psource=PERCENTILES2
# >> 82.21% complete. Working on SGSCA DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=SGSCA&percentiles=95&psource=PERCENTILES2
# >> 93.75% complete. Working on MATWW DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=MATWW&percentiles=95&psource=PERCENTILES2
# >> 99.04% complete. Working on AV356 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=AV356&percentiles=95&psource=PERCENTILES2
# >> 99.52% complete. Working on F2270 DID NOT WORK: http://api.synopticlabs.org/v2/percentiles?&token=2562b729557f45f5958516081f06c9eb&start=100906&end=100906&vars=wind_speed&stid=F2270&percentiles=95&psource=PERCENTILES2
# >> Data retrieval 100% complete. # stations with more than three years: 110

# %%
for s in data_CA['STATION']:
    if 'years' in s:
        print s['years'], s['STID'], s['HR_per']-s['MW_per']
# Out:
# [20] KSTS -1.114
# [20] KUKI -0.268
# [18] BNVC1 -0.244
# [18] BKSC1 0.697
# [18] WISC1 2.143
# [18] HWKC1 2.07
# [18] HGLC1 -0.008
# [18] KNXC1 0.877
# [18] COWC1 -2.221
# [18] RSAC1 -0.552
# [16] HPDC1 -1.664
# [8] NPYC1 -3.87
# [8] TMPC1 -2.407
# [16] KELC1 0.524
# [5] CQ039 2.359
# [11] CQ063 -0.002
# [14] C0622 2.879
# [14] C0677 1.088
# [14] CI077 1.184
# [14] CI083 0.439
# [13] CI085 2.516
# [14] CI103 0.402
# [14] CI106 0.965
# [14] CI109 0.503
# [14] CI144 1.444
# [14] CI158 2.672
# [13] C1766 2.697
# [13] AR323 2.777
# [4] PREC1 -0.836
# [3] H0237 1.404
# [4] H0300 3.312
# [4] H0447 0.436
# [4] H0452 3.672
# [4] H0505 0.951
# [12] CQ136 -0.916
# [5] CQ156 0.278
# [12] C3627 2.243
# [12] C3628 1.518
# [3] C3724 2.025
# [12] AR834 3.333
# [12] CI196 1.584
# [10] C3931 2.629
# [9] C4897 2.085
# [8] C5671 2.336
# [11] C5786 0.33
# [8] CQ176 -1.619
# [11] 46013 -1.531
# [4] C6576 0.305
# [11] PTRCA -1.912
# [7] C6940 1.786
# [10] AS725 2.187
# [9] KDVO 0.917
# [9] KHES 1.756
# [9] AT068 1.64
# [7] D1660 2.486
# [9] D1970 2.586
# [8] D2144 3.301
# [8] D2695 1.301
# [8] D2849 4.022
# [8] D3481 3.024
# [8] D3838 3.216
# [7] D4134 4.137
# [3] D4315 1.958
# [7] D4623 3.689
# [7] CQ214 0.282
# [7] CDW 1.772
# [4] D6443 2.815
# [6] AT925 5.407
# [6] ATLC1 -2.119
# [4] D7299 0.117
# [5] D7377 2.894
# [6] D8496 3.898
# [6] D8561 5.857
# [6] KO69 -0.539
# [5] D9528 1.978
# [4] D9521 3.34
# [5] D9840 1.967
# [5] D9878 3.331
# [5] D9841 4.861
# [5] D9883 5.746
# [5] AU415 3.271
# [5] D9961 1.876
# [5] E0433 1.702
# [5] AU487 4.014
# [5] E1553 2.966
# [4] E0176 2.578
# [4] E0674 4.928
# [4] E1582 2.03
# [4] E1763 1.722
# [3] E1866 3.86
# [4] E2050 2.487
# [4] E2362 2.92
# [4] RSWC1 4.647
# [4] BGAC1 -1.682
# [4] E3209 1.088
# [4] E3235 4.394
# [4] LKRC1 2.401
# [4] UCBM -0.123
# [3] E4371 5.071
# [3] E4393 2.057
# [3] BGDC1 0.417
# [3] SKGC1 1.265
# [3] CZCC1 -0.96
# [3] MCHC1 -1.015
# [3] E4777 0.533
# [3] RZAC1 1.022
# [3] E5234 3.162
# [3] E5568 5.407
# [3] E5780 2.473
# [3] E6035 5.602

# %% [markdown]
# ### Plot data

# %%
add_cities = False
add_fireperim = True

# %%
# plot difference
m.arcgisimage(service='World_Shaded_Relief', dpi=100)
m.drawstates()
m.drawcounties()
max_diff = 0
min_diff = 0
for s in data_CA['STATION']:
    if 'years' in s and s['years'] >= 3:
        m.scatter(float(s['LONGITUDE']), float(s['LATITUDE']),
                  latlon=True,
                  c=s['HR_per']-s['MW_per'],
                  linewidth=.5,
                  edgecolor='k',
                  s=50,
                  cmap='PiYG',
                  vmin=-5, vmax=5,
                  zorder=10)
        if s['HR_per']-s['MW_per'] > max_diff:
            max_diff = s['HR_per']-s['MW_per']
        if s['HR_per']-s['MW_per'] < min_diff:
            min_diff = s['HR_per']-s['MW_per']

cb = plt.colorbar(orientation='horizontal', pad=.01, shrink=.7)
cb.set_label(r'%s$\mathregular{^{th}}$ ' % p + 'Percentile %s Difference (%s)' % (label, units))
cb.set_ticks([range(-5,6)])

#plt.title(r'%s$\mathregular{^{th}}$' % p + 'Percentile Difference\n', fontweight='semibold', fontsize=15)
#plt.title(DATE.strftime('%d %B'), fontweight='semibold', loc='left')
#plt.title(DATE.strftime('%H:%M UTC'), fontweight='semibold', loc='right')
#plt.xlabel(r'HRRR %s$\mathregular{^{th}}$ - MesoWest %s$\mathregular{^{th}}$' % (p,p))

if add_cities:
    cities = {'Geyserville': (38.700078, -122.883772),
              'Santa Rosa': (38.452214, -122.717661),
              'Healdsburg': (38.606396, -122.869722),
              'Cloverdale': (38.794959, -123.006450),
              'Middletown': (38.750411, -122.615162),
              'Clearlake': (38.950727, -122.620816),
              'Calistoga': (38.580932, -122.580472)}

    import matplotlib.patheffects as path_effects
    for c in cities:
        text = plt.text(cities[c][1], cities[c][0], c,
                        color='white', ha='center', va='center')
        text.set_path_effects([path_effects.Stroke(linewidth=2, foreground='black'),
                               path_effects.Normal()])


if add_fireperim:
    pocket = '/uufs/chpc.utah.edu/common/home/u0553130/oper/HRRR_fires/fire_shapefiles/2017_pocket/ca_pocket_20171025_2130_dd83'
    m.readshapefile(pocket, 'pocket', drawbounds=False)
    
    tubbs = '/uufs/chpc.utah.edu/common/home/u0553130/oper/HRRR_fires/fire_shapefiles/2017_tubbs/ca_tubbs_20171025_2130_dd83'
    m.readshapefile(tubbs, 'tubbs', drawbounds=False)
    
    nuns = '/uufs/chpc.utah.edu/common/home/u0553130/oper/HRRR_fires/fire_shapefiles/2017_nuns/ca_nuns_20171025_2130_dd83'
    m.readshapefile(nuns, 'nuns', drawbounds=False)

    for info, shape in zip(m.pocket, m.pocket):
        fire_x, fir_y = zip(*shape) 
        m.plot(fire_x, fir_y, marker=None, color='darkred')
    for info, shape in zip(m.tubbs, m.tubbs):
        fire_x, fir_y = zip(*shape) 
        m.plot(fire_x, fir_y, marker=None, color='darkred')
    for info, shape in zip(m.nuns, m.nuns):
        fire_x, fir_y = zip(*shape) 
        m.plot(fire_x, fir_y, marker=None, color='darkred')
#plt.savefig('./figs/Fig_08_95th_HRRR_MW_difference')

print max_diff, min_diff
print DATE
print 'HRRR 95th - MesoWest 95th'
# Out:
# 5.857 -3.87
# 2017-10-09 06:00:00
# HRRR 95th - MesoWest 95th

# %%
# Get HRRR 95th percentile for the valid date
p95 = get_OSG_percentiles(DATE, percentile=95)

# %% [markdown]
# ### F12 forecast

# %%
for fxx in range(6,19,6):
    # HRRR at time of interest
    RUNDATE = DATE-timedelta(hours=fxx)
    H = get_hrrr_variable(RUNDATE, 'UVGRD:10 m', fxx=fxx, verbose=False)

    print 'Valid:\t\t%s\nInitalized:\t%s' % (H['valid'].strftime('%Y-%m-%d %H:%M'), H['anlys'].strftime('%Y-%m-%d %H:%M'))

    fig, (ax1, ax2) = plt.subplots(1,2, figsize=[7,3.8])

    cmap = 'viridis'

    add_fireperim = True

    # HRRR forecast - Observation 95th Percenitle
    plt.sca(ax1)
    m.arcgisimage(service='World_Shaded_Relief', dpi=1000)
    m.drawcounties(linewidth=.25)

    for s in data_CA['STATION']:
        if 'years' in s and s['years'] >= 3:
            # Pluck the HRRR forecast value for the nearest point
            MWlat = float(s['LATITUDE'])
            MWlon = float(s['LONGITUDE'])
            x, y = pluck_hrrr_point(H, MWlat, MWlon, XY_only=True, verbose=False)
            Hpoint = H['SPEED'][x][y]

            # Plot stations where HRRR analysis is greater than station 95th, else plot an empty marker
            if Hpoint-s['MW_per'] > 0:
                m.scatter(MWlon, MWlat,
                          c=Hpoint-s['MW_per'],
                          latlon=True,
                          linewidth=.5,
                          edgecolor='k',
                          s=40,
                          cmap=cmap,
                          vmin=0, vmax=14,
                          zorder=10)
            else:
                m.scatter(MWlon, MWlat,
                          latlon=True,
                          facecolors='none',
                          edgecolors='k',
                          linewidth=.5,
                          s=25,
                          zorder=10)

    ax1.set_ylabel('F%02d' % fxx, fontweight='semibold')
    #plt.title(DATE.strftime('%d %B 2017'), fontweight='semibold', loc='left')
    #plt.title(DATE.strftime('%H:%M UTC'), fontweight='semibold', loc='right')
    #plt.xlabel(r'HRRR F%02d - MesoWest %s$\mathregular{^{th}}$' % (fxx,p))


    if add_fireperim:
        pocket = '/uufs/chpc.utah.edu/common/home/u0553130/oper/HRRR_fires/fire_shapefiles/2017_pocket/ca_pocket_20171025_2130_dd83'
        m.readshapefile(pocket, 'pocket', drawbounds=False)

        tubbs = '/uufs/chpc.utah.edu/common/home/u0553130/oper/HRRR_fires/fire_shapefiles/2017_tubbs/ca_tubbs_20171025_2130_dd83'
        m.readshapefile(tubbs, 'tubbs', drawbounds=False)

        nuns = '/uufs/chpc.utah.edu/common/home/u0553130/oper/HRRR_fires/fire_shapefiles/2017_nuns/ca_nuns_20171025_2130_dd83'
        m.readshapefile(nuns, 'nuns', drawbounds=False)

        for info, shape in zip(m.pocket, m.pocket):
            fire_x, fir_y = zip(*shape) 
            m.plot(fire_x, fir_y, marker=None, color='darkred', linewidth=1)
        for info, shape in zip(m.tubbs, m.tubbs):
            fire_x, fir_y = zip(*shape) 
            m.plot(fire_x, fir_y, marker=None, color='darkred', linewidth=1)
        for info, shape in zip(m.nuns, m.nuns):
            fire_x, fir_y = zip(*shape) 
            m.plot(fire_x, fir_y, marker=None, color='darkred', linewidth=1)

    plt.sca(ax2)
    # plot difference
    m.arcgisimage(service='World_Shaded_Relief', dpi=1000)
    m.drawcounties(linewidth=.25)


    masked = H['SPEED']-p95
    masked = np.ma.array(masked)
    masked[masked < 0] = np.ma.masked


    pcm = m.pcolormesh(H['lon'], H['lat'], masked,
                       vmax=14, vmin=0,
                       cmap=cmap)


    # Wind barbs
    # Cut box for plotting barbs
    thin = 1
    subset = hrrr_subset(H, half_box=30, lat=mapCenterLat, lon=mapCenterLon)
    m.barbs(subset['lons'][::thin,::thin], subset['lats'][::thin,::thin],
            subset['UGRD'][::thin,::thin], subset['VGRD'][::thin,::thin],
            zorder=10, length=3.7, linewidth=.45,
            barb_increments={'half':2.5, 'full':5,'flag':25},
            latlon=True)

    #plt.title(DATE.strftime('%d %B 2017'), fontweight='semibold', loc='left')
    #plt.title(DATE.strftime('%H:%M UTC'), fontweight='semibold', loc='right')
    #plt.xlabel(r'HRRR F%02d - HRRR %s$\mathregular{^{th}}$' % (fxx, p))

    if add_fireperim:
        pocket = '/uufs/chpc.utah.edu/common/home/u0553130/oper/HRRR_fires/fire_shapefiles/2017_pocket/ca_pocket_20171025_2130_dd83'
        m.readshapefile(pocket, 'pocket', drawbounds=False)

        tubbs = '/uufs/chpc.utah.edu/common/home/u0553130/oper/HRRR_fires/fire_shapefiles/2017_tubbs/ca_tubbs_20171025_2130_dd83'
        m.readshapefile(tubbs, 'tubbs', drawbounds=False)

        nuns = '/uufs/chpc.utah.edu/common/home/u0553130/oper/HRRR_fires/fire_shapefiles/2017_nuns/ca_nuns_20171025_2130_dd83'
        m.readshapefile(nuns, 'nuns', drawbounds=False)

        for info, shape in zip(m.pocket, m.pocket):
            fire_x, fir_y = zip(*shape) 
            m.plot(fire_x, fir_y, marker=None, color='darkred', linewidth=1, zorder=5)
        for info, shape in zip(m.tubbs, m.tubbs):
            fire_x, fir_y = zip(*shape) 
            m.plot(fire_x, fir_y, marker=None, color='darkred', linewidth=1, zorder=5)
        for info, shape in zip(m.nuns, m.nuns):
            fire_x, fir_y = zip(*shape) 
            m.plot(fire_x, fir_y, marker=None, color='darkred', linewidth=1, zorder=5)


    fig.subplots_adjust(hspace=0, wspace=0.02, top=1)
    cbar_ax = fig.add_axes([0.16, 0.15, 0.7, 0.04]) # [left, bottom, width, height]
    cb = fig.colorbar(pcm, cax=cbar_ax, ticks=range(0,15,2), orientation='horizontal')
    cb.ax.set_xlabel(r'95$\mathregular{^{th}}$ Percentile Speed Exceedance (%s)' % (units))

    plt.savefig('./figs/Fig_07_95th_wind_map_f%02d' % fxx)

    print DATE.strftime('%d %B 2017 %H:%M UTC --- F'+'%02d'%fxx)
# Out:
# Valid:		2017-10-09 06:00
# Initalized:	2017-10-09 00:00
#  >> Requested Center lat: 38.715086	 lon: -122.777058
#  >>     Plucked HRRR lat: 38.717475272	 lon: -122.787664666
#  >>     Plucked from   x: 637	   y: 177
#  >> Size of subset: 60 x 60 grid points
# 09 October 2017 06:00 UTC --- F06
# Valid:		2017-10-09 06:00
# Initalized:	2017-10-08 18:00
#  >> Requested Center lat: 38.715086	 lon: -122.777058
#  >>     Plucked HRRR lat: 38.717475272	 lon: -122.787664666
#  >>     Plucked from   x: 637	   y: 177
#  >> Size of subset: 60 x 60 grid points
# 09 October 2017 06:00 UTC --- F12
# Valid:		2017-10-09 06:00
# Initalized:	2017-10-08 12:00
#  >> Requested Center lat: 38.715086	 lon: -122.777058
#  >>     Plucked HRRR lat: 38.717475272	 lon: -122.787664666
#  >>     Plucked from   x: 637	   y: 177
#  >> Size of subset: 60 x 60 grid points
# 09 October 2017 06:00 UTC --- F18
